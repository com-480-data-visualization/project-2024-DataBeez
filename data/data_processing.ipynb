# %%
import pandas as pd

# Load the dataset
file_path = 'World Important Dates.csv'
data = pd.read_csv(file_path)

# Display the unique types of events and the first few rows of the dataset
unique_events = data['Type of Event'].unique()
data.head(), unique_events
# Out:
# (   Sl. No                      Name of Incident     Date    Month     Year  \
#  0       1  Indus Valley Civilization Flourishes  Unknown  Unknown  2600 BC
#  1       2               Battle of the Ten Kings  Unknown  Unknown  1400 BC
#  2       6  Establishment of the Delhi Sultanate  Unknown  Unknown     1206
#  3       7                     Battle of Panipat       21    April     1526
#  4       8          Establishment of British Raj        1      May     1858
#
#    Country Type of Event    Place Name  \
#  0   India  Civilization  Indus Valley
#  1   India        Battle        Punjab
#  2   India     Political         Delhi
#  3   India        Battle       Panipat
#  4   India      Colonial   Whole India
#
#                                                Impact  \
#  0  Development of one of the world's earliest urb...
#  1  Rigvedic tribes consolidated their control ove...
#  2          Muslim rule established in parts of India
# ...

# %%
event_mapping = {
    # Political Events
    'Political': 'Political Events',
    'Judiciary': 'Political Events',
    'Legislative': 'Political Events',
    'Political Corruption': 'Political Events',
    'Political Party': 'Political Events',
    'Political Declaration': 'Political Events',
    'Political Integration': 'Political Events',
    'Political Formation': 'Political Events',
    'Political Transition': 'Political Events',
    'Political/Social Movement': 'Political Events',
    'Political Protest': 'Political Events',
    'Political Agreement': 'Political Events',
    'Political Crisis': 'Political Events',
    'Political Change': 'Political Events',
    'Political Scandal': 'Political Events',
    'Political/Economic Reform': 'Political Events',
    'Political/Military': 'Political Events',
    'Political Union': 'Political Events',
    'Political Revolution': 'Political Events',
    'Judicial Execution': 'Political Events',
    'Era Change': 'Political Events',
    'Federation': 'Political Events',
    'Coronation': 'Political Events',
    'Peace Process': 'Political Events',
    'Treaty': 'Political Events',
    'Commemoration': 'Political Events',
    'Land Reform': 'Political Events',
    'Housing Policy': 'Political Events',

    # Military and Conflict
    'Battle': 'Military and Conflict',
    'Military Operation': 'Military and Conflict',
    'Military Conflict': 'Military and Conflict',
    'War': 'Military and Conflict',
    'Military Rebellion': 'Military and Conflict',
    'Military Invasion': 'Military and Conflict',
    'Military Siege': 'Military and Conflict',
    'Military/Political Event': 'Military and Conflict',
    'Military/Atomic Warfare': 'Military and Conflict',
    'Military Occupation': 'Military and Conflict',
    'Military Engagement': 'Military and Conflict',
    'Military Withdrawal': 'Military and Conflict',
    'Conflict': 'Military and Conflict',
    'Civil War': 'Military and Conflict',
    'Independence': 'Military and Conflict',
    'Independence Movement': 'Military and Conflict',
    'Independence/Union': 'Military and Conflict',
    'Ceasefire': 'Military and Conflict',
    'Empire Fall': 'Military and Conflict',
    'Rebellion': 'Military and Conflict',

    # Economic and Infrastructure Development
    'Economic Policy': 'Economic and Infrastructure Development',
    'Economic Reform': 'Economic and Infrastructure Development',
    'Economic Crisis': 'Economic and Infrastructure Development',
    'Economic Development': 'Economic and Infrastructure Development',
    'Economic Boom': 'Economic and Infrastructure Development',
    'Economic/Social Reform': 'Economic and Infrastructure Development',
    'Economic/Infrastructure': 'Economic and Infrastructure Development',
    'Infrastructure': 'Economic and Infrastructure Development',
    'Infrastructure Development': 'Economic and Infrastructure Development',
    'Economic Nationalism': 'Economic and Infrastructure Development',
    'Economic and Infrastructure Project': 'Economic and Infrastructure Development',

    # Social and Cultural Events
    'Cultural/Political': 'Social and Cultural Events',
    'Cultural Heritage': 'Social and Cultural Events',
    'Cultural/Economic': 'Social and Cultural Events',
    'Cultural and Political Movement': 'Social and Cultural Events',
    'Cultural Shift': 'Social and Cultural Events',
    'Cultural Infrastructure': 'Social and Cultural Events',
    'Cultural Events': 'Social and Cultural Events',
    'Religious/Cultural': 'Social and Cultural Events',
    'Cultural Development': 'Social and Cultural Events',
    'Social Reform': 'Social and Cultural Events',
    'Social Policy': 'Social and Cultural Events',
    'Social Movement': 'Social and Cultural Events',
    'Social Justice': 'Social and Cultural Events',
    'Cultural': 'Social and Cultural Events',
    'Sports': 'Social and Cultural Events',
    'Media Development': 'Social and Cultural Events',
    'Royal Event': 'Social and Cultural Events',

    # Technological and Scientific Advancements
    'Technology': 'Technological and Scientific Advancements',
    'Space Exploration': 'Technological and Scientific Advancements',
    'Scientific': 'Technological and Scientific Advancements',
    'Engineering Achievement': 'Technological and Scientific Advancements',
    'Scientific Achievement': 'Technological and Scientific Advancements',
    'Technological Advancement': 'Technological and Scientific Advancements',
    'Discovery': 'Technological and Scientific Advancements',
    'Aviation': 'Technological and Scientific Advancements',
    'Maritime': 'Technological and Scientific Advancements',
    'Nuclear Test': 'Technological and Scientific Advancements',
    'Educational Development': 'Technological and Scientific Advancements',

    # Environmental and Health
    'Environmental/Economic Policy': 'Environmental and Health',
    'Health Policy': 'Environmental and Health',
    'Health Crisis': 'Environmental and Health',
    'Public Health': 'Environmental and Health',
    'Environmental Policy': 'Environmental and Health',
    'Pandemic': 'Environmental and Health',
    'Natural Disaster': 'Environmental and Health',

    # Legal and Judicial Changes
    'Legal': 'Legal and Judicial Changes',
    'Judicial': 'Legal and Judicial Changes',
    'Legal/Social': 'Legal and Judicial Changes',
    'Legal/Political': 'Legal and Judicial Changes',
    'Legal Framework': 'Legal and Judicial Changes',
    'Legal Inquiry': 'Legal and Judicial Changes',
    'Legal Code Introduction': 'Legal and Judicial Changes',
    'Legal Land Rights': 'Legal and Judicial Changes',
    'Judicial/Political': 'Legal and Judicial Changes',
    'Legal System Implementation': 'Legal and Judicial Changes',

    # International Relations and Diplomacy
    'International Relations': 'International Relations and Diplomacy',
    'International Agreement': 'International Relations and Diplomacy',
    'International Integration': 'International Relations and Diplomacy',
    'International Cooperation': 'International Relations and Diplomacy',
    'International Sports Event': 'International Relations and Diplomacy',
    'Diplomatic': 'International Relations and Diplomacy',
    'Diplomatic Agreement': 'International Relations and Diplomacy',
    'International Policy': 'International Relations and Diplomacy',
    'International Economic Integration': 'International Relations and Diplomacy',
    'International Economic Agreement': 'International Relations and Diplomacy',
    'International Summit': 'International Relations and Diplomacy',

    # Crisis and Emergency Response
    'Terrorism': 'Crisis and Emergency Response',
    'Massacre': 'Crisis and Emergency Response',
    'Genocide': 'Crisis and Emergency Response',
    'Disaster': 'Crisis and Emergency Response',
    'Humanitarian': 'Crisis and Emergency Response',
    'Rescue Operation': 'Crisis and Emergency Response',
    'Structural Failure': 'Crisis and Emergency Response',

    # Historical and Monumental
    'Archaeological Discovery': 'Historical and Monumental',
    'Mausoleum': 'Historical and Monumental',
    'Monument': 'Historical and Monumental',
    'Historical Reconciliation': 'Historical and Monumental',
    'Foundational Document': 'Historical and Monumental',
    'Historical Period': 'Historical and Monumental',
    'Dynastic Transition': 'Historical and Monumental',

    'Civil Disobedience Movement': 'Political Events',
    'Violent Protest': 'Political Events',
    'Civil Disobedience': 'Political Events',
    'Conference': 'Political Events',
    'Mass Protest': 'Political Events',
    'Negotiation': 'Political Events',
    'Political Decision': 'Political Events',
    'Constitutional Adoption': 'Political Events',
    'Regulatory Body': 'Political Events',
    'Country Formation': 'Political Events',
    'Constitutional': 'Political Events',
    'Political Movement': 'Political Events',
    'Diplomatic/Religious': 'Political Events',
    'International Finance': 'Political Events',
    'Scientific Organization': 'Political Events',
    'International Recognition': 'Political Events',
    'Social Welfare Program': 'Political Events',
    'Constitutional Amendment': 'Political Events',
    'Government Agency': 'Political Events',
    'Security Policy': 'Political Events',
    'Ethnic Conflict': 'Political Events',
    'Education Policy': 'Political Events',
    'Land Policy': 'Political Events',
    'Political/Territorial Change': 'Political Events',
    'International Incident': 'Political Events',
    'Foreign Policy': 'Political Events',
    'Diplomatic Mission': 'Political Events',
    'International Treaty': 'Political Events',
    'Diplomatic Meeting': 'Political Events',
    'International Conference': 'Political Events',
    'International Crisis': 'Political Events',
    'Military Intervention': 'Political Events',
    'Nuclear Accident': 'Political Events',
    'Political Repression': 'Political Events',
    'End of WWII in Europe': 'Political Events',
    'End of WWII': 'Political Events',
    'Political Reform': 'Political Events',
    'Political Assassination': 'Political Events',
    'Annexation': 'Political Events',
    'Exile Government Formation': 'Political Events',
    'End of Colonial Rule': 'Political Events',
    'Geopolitical Division': 'Political Events',
    'State Establishment': 'Political Events',
    'Political Ideology': 'Political Events',
    'Political Uprising': 'Political Events',
    'Military Coup': 'Political Events',
    'Democratic Uprising': 'Political Events',
    'Diplomatic Policy': 'Political Events',
    'Leadership Change': 'Political Events',
    'Political/Military Organization': 'Political Events',
    'Military Offensive': 'Political Events',
    'International Trade Membership': 'Political Events',
    'Political Consolidation': 'Political Events',
    'Colonial Occupation': 'Political Events',
    'Assassination Attempt': 'Political Events',
    'Armed Rebellion': 'Political Events',
    'Declaration of Independence': 'Political Events',
    'Resistance Movement': 'Political Events',
    'Military Defeat': 'Political Events',
    'Political Unification': 'Political Events',
    'Diplomatic Recognition': 'Political Events',
    'Security Incident': 'Political Events',
    'Regional Conflict': 'Political Events',
    'Economic Integration': 'Political Events',
    'Economic/Social Reform Plan': 'Political Events',
    'Political Action': 'Political Events',
    'Diplomatic Incident': 'Political Events',
    'AntiUnknownCorruption Effort': 'Political Events',
    'Administrative Change': 'Political Events',
    'Military Administration': 'Political Events',
    'Reconstruction': 'Political Events',
    'Independence Declaration': 'Political Events',
    'Cultural Policy': 'Political Events',
    'Military Surrender': 'Political Events',
    'Colonial Rule': 'Political Events',
    'Administrative Reorganization': 'Political Events',
    'Colonial Subjugation': 'Political Events',
    'Political Dominion': 'Political Events',
    'Sultanate Formation': 'Political Events',
    'Military Conquest': 'Political Events',
    'City Foundation': 'Political Events',
    'Political Annexation': 'Political Events',
    'Empire Peak': 'Political Events',
    'Country Unification': 'Political Events',
    'Political Restoration': 'Political Events',
    'Political Reorganization': 'Political Events',
    'Military Alliance': 'Political Events',
    'Political Rebellion': 'Political Events',
    'Constitutional Development': 'Political Events',
    'CounterUnknownInsurgency': 'Political Events',
    'Modernization Policy': 'Political Events',
    'Monarchy Establishment': 'Political Events',
    'Economic Shift': 'Political Events',
    'Colonial Administration': 'Political Events',
    'Nationalization': 'Political Events',
    'Protectorate Establishment': 'Political Events',
    'Secession Attempt': 'Political Events',
    'Political Coup': 'Political Events',
    'Revolution': 'Political Events',
    'Cultural Change': 'Political Events',
    'Corruption Scandal': 'Political Events',
    'Diplomatic Event': 'Political Events',
    'Human Rights Improvement': 'Political Events',
    'Legal Reform': 'Political Events',
    'Electoral Victory': 'Political Events',
    'General Election': 'Political Events',
    'Electoral Reform': 'Political Events',
    'Constitutional Reform': 'Political Events',
    'Political Development': 'Political Events',
    'Political/Social Reform': 'Political Events',
    'Social Unrest': 'Political Events',
    'Civil Rights': 'Political Events',
    'Environmental Legislation': 'Political Events',
    'Policy/Legislation': 'Political Events',
    'Defense Policy': 'Political Events',
    'Political Framework': 'Political Events',
    'Political Inclusion': 'Political Events',
    'Legal/Constitutional': 'Political Events',
    'Constitutional/Legal': 'Political Events',
    'Political/Legal': 'Political Events',
    'Gun Violence': 'Political Events',
    'Cultural/Legal': 'Political Events',

    # Military and Conflict
    'Military': 'Military and Conflict',
    'Military/Strategic Retreat': 'Military and Conflict',
    'Military Battle': 'Military and Conflict',

    # Economic and Infrastructure Development
    'Economic': 'Economic and Infrastructure Development',
    'Modernization/Expansion': 'Economic and Infrastructure Development',
    'Economic Innovation': 'Economic and Infrastructure Development',
    'Labor Movement': 'Economic and Infrastructure Development',
    'Settlement': 'Economic and Infrastructure Development',
    'Military Formation': 'Economic and Infrastructure Development',
    'Military Campaign': 'Economic and Infrastructure Development',
    'Agricultural Development': 'Economic and Infrastructure Development',
    'Agricultural Policy': 'Economic and Infrastructure Development',
    'Territorial Expansion': 'Economic and Infrastructure Development',

    # Social and Cultural Events
    'Education': 'Social and Cultural Events',
    'Financial Technology': 'Social and Cultural Events',
    'Telecommunications': 'Social and Cultural Events',
    'Wildlife Conservation': 'Social and Cultural Events',
    'Environmental/Social': 'Social and Cultural Events',
    'Education Development': 'Social and Cultural Events',
    'Architectural/Defensive': 'Social and Cultural Events',
    'Dynastic Founding': 'Social and Cultural Events',
    'International Conflict': 'Social and Cultural Events',
    'Trade Route Development': 'Social and Cultural Events',
    'AntiUnknownImperialist Uprising': 'Social and Cultural Events',
    'Population Control Policy': 'Social and Cultural Events',
    'Sovereignty Transition': 'Social and Cultural Events',
    'International Organization': 'Social and Cultural Events',
    'Architectural': 'Social and Cultural Events',
    'Cultural/Religious Exchange': 'Social and Cultural Events',
    'International Exhibition': 'Social and Cultural Events',
    'State Formation': 'Social and Cultural Events',
    'Political/Religious Movement': 'Social and Cultural Events',
    'Social Welfare': 'Social and Cultural Events',
    'Political Party Formation': 'Social and Cultural Events',
    'National Commemoration': 'Social and Cultural Events',
    'Election': 'Social and Cultural Events',
    'Social Welfare Legislation': 'Social and Cultural Events',
    'Military/Science': 'Social and Cultural Events',
    'Economic Aid': 'Social and Cultural Events',
    'PreUnknownRevolutionary Conflict': 'Social and Cultural Events',
    'Forced Relocation': 'Social and Cultural Events',
    'PostUnknownCivil War Reconstruction': 'Social and Cultural Events',
    'Economic/Social': 'Social and Cultural Events',
    'Medical': 'Social and Civil Rights',
    'Civil Rights Violation': 'Social and Cultural Events',
    'Religious Reformation': 'Social and Cultural Events',
    'Union': 'Social and Cultural Events',
    'Industrial': 'Social and Cultural Events',
    'Monarchical': 'Social and Cultural Events',
    'Transportation': 'Social and Cultural Events',
    'Sporting Event': 'Social and Cultural Events',
    'Health': 'Social and Cultural Events',
    'Innovation': 'Social and Cultural Events',
    'Media': 'Social and Cultural Events',
    'International Politics': 'Social and Cultural Events',
    'Prehistoric Monument': 'Social and Cultural Events',
    'Natural Event': 'Social and Cultural Events',
    'Crusade': 'Social and Cultural Events',
    'Execution': 'Social and Cultural Events',
    'Protests': 'Social and Cultural Events',
    'Sport': 'Social and Cultural Events',
    'Religious War': 'Social and Cultural Events',
    'Conquest': 'Social and Cultural Events',
    'Artistic Achievement': 'Social and Cultural Events',
    'Military Sack': 'Social and Cultural Events',
    'Unification': 'Social and Cultural Events',
    'Coup': 'Social and Cultural Events',
    'War Declaration': 'Social and Cultural Events',
    'Referendum': 'Social and Cultural Events',
    'Corruption Investigation': 'Social and Cultural Events',
    'Maritime Disaster': 'Social and Cultural Events',
    'World Expo': 'Social and Cultural Events',
    'Military/Religious Campaign': 'Social and Cultural Events',
    'Naval Engagement': 'Social and Cultural Events',
    'Peace Treaty': 'Social and Cultural Events',
    'Religious/Court': 'Social and Cultural Events',
    'Political/Economic Integration': 'Social and Cultural Events',
    'Religious/Political': 'Social and Cultural Events',
    'Naval Battle': 'Social and Cultural Events',
    'Dynastic Union': 'Social and Cultural Events',
    'Cultural Flourishing': 'Social and Cultural Events',
    'Colonial War': 'Social and Cultural Events',
    'Dictatorship': 'Social and Cultural Events',
    'International Event': 'Social and Cultural Events',
    'Political/Secession': 'Social and Cultural Events',
    'Peace/Security': 'Social and Cultural Events',
    'Religious Policy': 'Social and Cultural Events',
    'Colonial Legislation': 'Social and Cultural Events',
    'Economic/Cultural': 'Social and Cultural Events',
    'Religious': 'Social and Cultural Events',
    'Political Separation': 'Social and Cultural Events',
    'Foundational': 'Social and Cultural Events',
    'Engineering Marvel': 'Social and Cultural Events',
    'Religious/Military War': 'Social and Cultural Events',
    'Coup d\'état': 'Social and Cultural Events',
    'Peace Agreement': 'Social and Cultural Events',
    'General Elections': 'Social and Cultural Events',
    'Justice System': 'Social and Cultural Events',
    'Insurgency': 'Social and Cultural Events',
    'Protest Movement': 'Social and Cultural Events',
    'Urban Development': 'Social and Cultural Events',
    'Political/Social': 'Social and Cultural Events',
    'Pogrom': 'Social and Cultural Events',
    'Social': 'Social and Cultural Events',
    'Decline': 'Social and Cultural Events',

    # Technological and Scientific Advancements
    'Nuclear Energy': 'Technological and Scientific Advancements',
    'Educational Reform': 'Technological and Scientific Advancements',
    'Rail': 'Technological and Scientific Advancements',
    'Spacecraft Accident': 'Technological and Scientific Advancements',
    'Industrial Accident': 'Technological and Scientific Advancements',
    'Territorial Acquisition': 'Technological and Scientific Advancements',
    'Space Exploration Disaster': 'Technological and Scientific Advancements',
    'International': 'Technological and Scientific Advancements',
    'Domestic Terrorism': 'Technological and Scientific Advancements',
    'Political/Infrastructure': 'Technological and Scientific Advancements',
    'Social Movement/Legal': 'Technological and Scientific Advancements',
    'Environmental': 'Technological and Scientific Advancements',
    'Healthcare': 'Technological and Scientific Advancements',

    # Environmental and Health
    'Religious Shrine': 'Environmental and Health',

    # Crisis and Emergency Response
    'Accident': 'Crisis and Emergency Response'
}

# %%
# Map the existing event types to the new categories
data['Broad Category'] = data['Type of Event'].map(lambda x: event_mapping.get(x, 'Other'))

# Display the updated DataFrame and the distribution of new categories
data[['Type of Event', 'Broad Category']].head(), data['Broad Category'].value_counts()

data.to_csv('modified_data.csv', index=False)

# %%
# Find events that are still categorized as "Other" or not categorized at all (NaN values)
unmapped_events = data[data['Broad Category']=="Other"]['Type of Event'].unique()

# Save the list of unmapped event types to a CSV for review (optional)
unmapped_df = pd.DataFrame(unmapped_events, columns=['Unmapped Events'])
unmapped_df.to_csv('unmapped_events.csv', index=False)
