# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
df = pd.read_csv('World Important Dates.csv')
df.head()
# Out:
#    Sl. No                      Name of Incident     Date    Month     Year  \
# 0       1  Indus Valley Civilization Flourishes  Unknown  Unknown  2600 BC
# 1       2               Battle of the Ten Kings  Unknown  Unknown  1400 BC
# 2       6  Establishment of the Delhi Sultanate  Unknown  Unknown     1206
# 3       7                     Battle of Panipat       21    April     1526
# 4       8          Establishment of British Raj        1      May     1858
#
#   Country Type of Event    Place Name  \
# 0   India  Civilization  Indus Valley
# 1   India        Battle        Punjab
# 2   India     Political         Delhi
# 3   India        Battle       Panipat
# 4   India      Colonial   Whole India
#
#                                               Impact  \
# 0  Development of one of the world's earliest urb...
# 1  Rigvedic tribes consolidated their control ove...
# 2          Muslim rule established in parts of India
# 3           Foundation of the Mughal Empire in India
# 4        Start of direct British governance in India
#
#                        Affected Population Important Person/Group Responsible  \
# 0                        Local inhabitants                Indus Valley people
# 1                          Rigvedic tribes                              Sudas
# 2  People of Delhi and surrounding regions      QutbUnknownudUnknowndin Aibak
# 3                 Northern Indian kingdoms                              Babur
# 4                      Indian subcontinent  British East India Company/Empire
#
#     Outcome
# 0  Positive
# 1  Positive
# 2     Mixed
# 3     Mixed
# 4  Negative

# %%
df.columns
# Out:
# Index(['Sl. No', 'Name of Incident', 'Date', 'Month', 'Year', 'Country',
#        'Type of Event', 'Place Name', 'Impact', 'Affected Population',
#        'Important Person/Group Responsible', 'Outcome'],
#       dtype='object')

# %%
df.Country.unique()
# Out:
# array(['India', 'UK', 'Pakistan', 'Sri Lanka', 'China', 'Russia', 'USSR',
#        'Japan', 'Australia', 'New Zealand', 'Korea', 'South Korea',
#        'North Korea', 'Vietnam', 'Saudi Arabia', 'Singapore', 'Iran',
#        'Iraq', 'Almaty', 'Bukhara', 'Bhutan', 'Maldives', 'Malaya',
#        'Tehran', 'Kazakhstan', 'Samarkand', 'Thimphu', 'Malaysia',
#        'Babylon', 'Malacca', 'Persia', 'Uzbekistan', 'Central Asia',
#        'Basra', 'Tashkent', 'Punakha', 'Soviet Union', 'Uzbek SSR',
#        'Addu Atoll', 'Kuwait, Iraq', 'Mosul', 'Zhanaozen', 'Taiwan',
#        'Indonesia', 'Philippines', 'Thailand', 'USA', 'Canada', 'France',
#        'Italy', 'Spain', 'Spain/USA', 'South Africa', 'England',
#        'Gibraltar', 'Denmark', 'Norway', 'Finland', 'Nigeria', 'Kenya',
#        'Algeria', 'Libya', 'Tunisia', 'Zimbabwe', 'Morocco', 'Angola',
#        'Egypt', 'Rwanda', 'Uganda', 'Somalia', 'Botswana', 'Namibia',
#        'Sudan', "Côte d'Ivoire", 'Ghana', 'Tanzania', 'Madagascar',
#        'Ethiopia', 'Mozambique', 'Zambia', 'Senegal', 'Congo (DRC)',
#        'Sierra Leone', 'Mali', 'Burkina Faso', 'Cameroon', 'Eritrea',
#        'Benin', 'Mauritania', 'Gabon', 'Lesotho', 'Gambia', 'Djibouti',
#        'Equatorial Guinea', 'Seychelles', 'Cape Verde',
#        'GuineaUnknownBissau', 'Comoros', 'Central African Republic',
#        'Chad', 'Malawi', 'Burundi', 'Congo (Brazzaville)', 'Togo',
#        "Ivory Coast (Côte d'Ivoire)", 'Niger', 'Swaziland (Eswatini)',
#        'Guinea', 'South Sudan', 'Brazil', 'Germany', 'Argentina',
#        'Mexico'], dtype=object)

# %%
# Define your mapping dictionary
country_corrections = {
    "USSR": "Russia",
    "UK": "United Kingdom",
    "Soviet Union": "Russia", 
    "Uzbek SSR": "Uzbekistan",
    "Malaya": "Malaysia", 
    "Persia": "Iran", 
    "Babylon": "Iraq",
    "England": "United Kingdom", 
    "Spain/USA": "Multiple", 
    "Kuwait, Iraq": "Multiple",
    "Congo (DRC)": "Democratic Republic of the Congo", 
    "Congo (Brazzaville)": "Republic of the Congo",
    "Ivory Coast (Côte d'Ivoire)": "Côte d'Ivoire", 
    "Swaziland (Eswatini)": "Eswatini",
    "GuineaUnknownBissau": "Guinea-Bissau", 
    "USA": "United States", 
    "Vietnam": "Vietnam",
    "Almaty": "Kazakhstan", 
    "Bukhara": "Uzbekistan", 
    "Samarkand": "Uzbekistan",
    "Tehran": "Iran", 
    "Tashkent": "Uzbekistan", 
    "Thimphu": "Bhutan",
    "Basra": "Iraq", 
    "Mosul": "Iraq", 
    "Zhanaozen": "Kazakhstan",
    "Addu Atoll": "Maldives"
}

# Apply the mapping to your dataframe
df['Country'] = df['Country'].replace(country_corrections)

# Check the updated unique country names
df['Country'].unique()
# Out:
# array(['India', 'United Kingdom', 'Pakistan', 'Sri Lanka', 'China',
#        'Russia', 'Japan', 'Australia', 'New Zealand', 'Korea',
#        'South Korea', 'North Korea', 'Vietnam', 'Saudi Arabia',
#        'Singapore', 'Iran', 'Iraq', 'Kazakhstan', 'Uzbekistan', 'Bhutan',
#        'Maldives', 'Malaysia', 'Malacca', 'Central Asia', 'Punakha',
#        'Multiple', 'Taiwan', 'Indonesia', 'Philippines', 'Thailand',
#        'United States', 'Canada', 'France', 'Italy', 'Spain',
#        'South Africa', 'Gibraltar', 'Denmark', 'Norway', 'Finland',
#        'Nigeria', 'Kenya', 'Algeria', 'Libya', 'Tunisia', 'Zimbabwe',
#        'Morocco', 'Angola', 'Egypt', 'Rwanda', 'Uganda', 'Somalia',
#        'Botswana', 'Namibia', 'Sudan', "Côte d'Ivoire", 'Ghana',
#        'Tanzania', 'Madagascar', 'Ethiopia', 'Mozambique', 'Zambia',
#        'Senegal', 'Democratic Republic of the Congo', 'Sierra Leone',
#        'Mali', 'Burkina Faso', 'Cameroon', 'Eritrea', 'Benin',
#        'Mauritania', 'Gabon', 'Lesotho', 'Gambia', 'Djibouti',
#        'Equatorial Guinea', 'Seychelles', 'Cape Verde', 'Guinea-Bissau',
#        'Comoros', 'Central African Republic', 'Chad', 'Malawi', 'Burundi',
#        'Republic of the Congo', 'Togo', 'Niger', 'Eswatini', 'Guinea',
#        'South Sudan', 'Brazil', 'Germany', 'Argentina', 'Mexico'],
#       dtype=object)

# %%
df['Place Name'].unique()
# Out:
# array(['Indus Valley', 'Punjab', 'Delhi', 'Panipat', 'Whole India',
#        'India/Pakistan', 'Bangladesh', 'Pokhran', 'Mumbai', 'Calicut',
#        'Plassey', 'Meerut', 'Bengal', 'Punjab, Haryana', 'Amritsar',
#        'Kargil, Ladakh', 'India', 'New Delhi', 'Ayodhya', 'Maharashtra',
#        'Border regions of India', 'Pokhran, Rajasthan',
#        'Bhopal, Madhya Pradesh', 'Kandahar, Afghanistan',
#        'Jammu & Kashmir', 'Gujarat', 'Uttar Pradesh', "Lord's, England",
#        'Uttarakhand', 'Mars', 'South Africa', 'Nationwide', 'Moon',
#        'Pulwama, Jammu and Kashmir', 'Paris, France',
#        'Uri, Jammu and Kashmir', 'Bombay', 'Chauri Chaura', 'Dandi',
#        'London', 'Lahore', 'Various', 'Calcutta (now Kolkata)',
#        'Bangalore', 'Agra', 'Pakistan', 'Kashmir', 'New York', 'Dhaka',
#        'East Pakistan', 'Chagai, Balochistan', 'Kargil, Kashmir',
#        'Kashmir, Pakistan', 'Rawalpindi', 'North Waziristan', 'Peshawar',
#        'Islamabad', 'Kartarpur', 'Federally Administered Tribal Areas',
#        'Pulwama, India', 'Siachen Glacier', 'Karachi', 'Oslo, Norway',
#        'Khunjerab Pass to Hassan Abdal', 'Xichang, China', 'Gwadar',
#        'Colombo', 'Sri Lanka', 'Colombo, others', 'Coastal Sri Lanka',
#        'Mullaitivu', 'Mahaweli River', 'Sigiriya', 'Imperial court',
#        'Han Dynasty China', 'Northern China', "Chang'an", 'Kaifeng',
#        'Mongol Empire', 'China', 'Nanjing', 'Southern China', 'Wuchang',
#        'Jiangxi to Shaanxi', 'Hong Kong', 'Beijing',
#        'China to the Mediterranean', 'Yangtze River',
#        'Hangzhou to Beijing', 'Southeast Asia, Africa', 'Macau',
#        'Shanghai', "Chang'an, Luoyang", 'Yuan Dynasty China',
#        'Ming Dynasty China', 'Nanking', 'Beijing, Shanghai', 'Geneva',
#        'Guangdong', 'South China Sea', 'Brussels', 'Kiev', "Kievan Rus'",
#        'Kulikovo Field', 'Moscow', 'Russia', 'Manchuria, Korea',
#        'Petrograd (Saint Petersburg)', 'Soviet Union',
#        'BrestUnknownLitovsk (now Brest, Belarus)', 'Kronstadt',
#        'Soviet Russia', 'Finland', 'Leningrad (now Saint Petersburg)',
#        'Stalingrad (now Volgograd)', 'Yalta, Crimea',
#        'Baikonur Cosmodrome', 'Cuba', 'Czechoslovakia', 'Afghanistan',
#        'Chernobyl, Ukraine', 'Berlin, Germany', 'Beslan, North Ossetia',
#        'Crimea', 'Syria', 'Salisbury, UK', 'Asuka', 'Japan', 'Nara',
#        'HeianUnknownkyō (Kyoto)', 'Kamakura', 'Kyushu',
#        'Muromachi, Kyoto', 'Kyoto', 'Tanegashima', 'Azuchi',
#        'Edo (Tokyo)', 'Korea, China', 'Manchuria, China',
#        'Hiroshima, Nagasaki', 'Edo Bay (Tokyo Bay)', 'USA, Europe',
#        'Korea', 'Washington D.C.', 'Near Beijing, China', 'Tokyo Bay',
#        'San Francisco', 'Tokyo', 'Osaka', 'Kobe', 'Fukushima', 'Seoul',
#        'Sydney Cove', 'Tasmania', 'New South Wales, Victoria',
#        'Ballarat, Victoria', 'Entire Australia', 'Gallipoli, Turkey',
#        'Sydney', 'Darwin, Northern Territory', 'Papua New Guinea',
#        'Global', 'Myall Creek, New South Wales', 'Melbourne, Victoria',
#        'Queensland', 'Australia', 'Victoria', 'High Court of Australia',
#        'Vietnam', 'Canberra', 'Port Arthur, Tasmania', 'Canberra, London',
#        'Northern Territory', 'Australia, UK', 'Indian Ocean', 'Waitangi',
#        'Various locations', 'Otago, West Coast', 'Unknown', 'Tarawera',
#        'Europe, Pacific', 'Auckland', 'New Zealand', 'Christchurch',
#        'Kyoto, Japan', 'Korean Peninsula', 'Gyeongbokgung Palace',
#        'Korean Peninsula, Manchuria', 'Shanghai, China',
#        '38th Parallel North', 'Pyongyang', 'Jeju Island', 'South Korea',
#        'North Korea', 'Panmunjom', 'Sea of Japan', 'Kilju County',
#        'Gwangju', 'South Korea, Japan', 'Seongju County', 'Điện Biên Phủ',
#        'South Vietnam', 'Gulf of Tonkin', 'Paris', 'Saigon',
#        'Vietnam, US', 'Southeast Asia', 'Hanoi', 'Da Nang', 'Space',
#        'Hanoi, Ho Chi Minh City', 'Northern Vietnam', 'Southern Vietnam',
#        'Central Vietnam', 'Yên Bái', 'Ba Đình Square, Hanoi', 'Diriyah',
#        'Najd', 'Hejaz', 'Najd, Hejaz', 'Jeddah', 'Dammam', 'Dhahran',
#        'Saudi Arabia', 'Yemen border', 'Mecca', 'Riyadh', 'Taif',
#        'Middle East', 'Eastern Province', 'Cairo', 'Persian Gulf',
#        'Kuwait, Saudi Arabia', 'Yemen', 'Istanbul, Turkey', 'Singapore',
#        'Malaya', 'Malaysia', 'Sentosa', 'Iran', 'Mesopotamia',
#        'Kazakhstan', 'Bukhara', 'Punakha', 'Maldives', 'Iraq',
#        'Samarkand', 'Thimphu', 'Babylon', 'Bhutan', 'Malacca', 'Persia',
#        'Baghdad', 'Uzbekistan', 'Northern Kazakhstan', 'Kengir',
#        'Central asia', 'Peninsular', 'Basra', 'Tashkent', 'Addu Atoll',
#        'Iraq/Iran border', 'From Almaty to Astana', 'Astana',
#        'Kuala Lumpur', 'Mosul', 'Zhanaozen', 'Malé', 'NurUnknownSultan',
#        'Southern Indian Ocean', 'Mount Takamagahara', 'Taiwan Strait',
#        'Guam', 'Java Sea', 'Kathmandu', 'Okinawa', 'Musi River', 'Phuket',
#        'Yellow Sea', 'Fukushima Prefecture', 'Wenzhou', 'Tablas Strait',
#        'Sidoarjo', 'Tham Luang Cave', 'Philadelphia', 'Midwest',
#        'Southern USA', 'Wall Street, NY', 'NY, VA, PA', 'Topeka, Kansas',
#        'Cape Canaveral, FL', 'Oklahoma City, OK', 'Gulf Coast',
#        'USUnknownMexico Border', 'International', 'East Coast',
#        'Dallas, Texas', 'New York, NY', 'Silicon Valley, CA',
#        'Charlottesville, VA', 'Boston, MA', 'Western USA', 'California',
#        'Seneca Falls, NY', 'Confederate States', 'Promontory, Utah',
#        'Cuba, Philippines', 'Kitty Hawk, NC', 'Southwestern USA',
#        'Supreme Court', 'Western Territories', 'Panama', 'Europe',
#        'Pearl Harbor, HI', 'Western Europe', 'San Francisco, CA',
#        'Jamestown, VA', 'Salem, MA', 'Eastern North America',
#        'USA, Canada', 'Missouri', 'Southeastern USA', 'Kansas, Nebraska',
#        'Alaska', 'Ottawa', 'Vimy Ridge, France', 'Toronto',
#        'Newfoundland', 'Oka, Quebec', 'Vancouver', 'Fort McMurray, AB',
#        'Northern Canada', 'Quebec', 'Red River Colony', 'Yukon',
#        'Halifax, NS', 'British Columbia', 'Leduc, Alberta', 'London, UK',
#        'Runnymede', 'English Channel', 'England', 'Scotland and England',
#        'Trafalgar', 'Parliament', 'Suez Canal', 'Liverpool',
#        'Falkland Islands', 'Northern Ireland', 'UK',
#        'Stockton to Darlington', 'Skies over Britain', 'Aldermaston',
#        'Scotland', 'London and nationwide', 'Windsor', 'France',
#        'Waterloo', "St Mary's Hospital", 'Westminster Abbey',
#        'Roslin Institute', 'Gleneagles', 'Salisbury Plain', 'Oxford',
#        'Agincourt', 'Derry', 'Tours', 'Verdun', 'Rome', 'Clermont',
#        'Orléans', 'Nantes', 'Clermont (announced)', 'Lodi',
#        'Constantinople (Impact on Italy)', 'Florence', 'Venice',
#        'Utrecht (Impact on Italy)', 'Turin', 'Milan', "L'Aquila",
#        'Giglio Island', 'Atlantic Ocean', 'Granada', 'Pyrenees',
#        'Caribbean, Pacific', 'Spain', 'Madrid',
#        'Cuba, Philippines, Puerto Rico, Guam', 'Americas',
#        'Atlantic Ocean near Cape Trafalgar', 'Utrecht',
#        'Iberian Peninsula', 'Cadiz', 'Barcelona', 'Catalonia',
#        'Valle de los Caídos', 'Basque Country', 'Altamira', 'Worldwide',
#        'Johannesburg', 'Between MadridUnknownSeville', 'Gibraltar',
#        'Spanish America', 'Gadir (Cádiz)', 'Guadalete River', 'Denmark',
#        'Norway', 'Kalmar, Sweden', 'Roskilde', 'Copenhagen', 'Lapland',
#        'Schleswig', 'Oslo', 'Fredrikshamn', 'Kimberley', 'Nigeria',
#        'Kenya', 'Algeria', 'Libya', 'Tunisia', 'Great Zimbabwe',
#        'Marrakech', 'Angola', 'Rwanda', 'Uganda', 'Somalia', 'Botswana',
#        'Namibia', 'Sudan', "Côte d'Ivoire", 'Ghana', 'Tanzania',
#        'Madagascar', 'Ethiopia', 'Sharpeville', 'Algiers', 'Mozambique',
#        'Zambia', 'Senegal', 'Congo (DRC)', 'Sierra Leone', 'Mali',
#        'Burkina Faso', 'Zimbabwe', 'Egypt', 'Cameroon', 'Eritrea',
#        'Arusha, Tanzania', 'Benin (Dahomey)', 'Mauritania', 'Gabon',
#        'Lesotho', 'Gambia', 'Djibouti', 'Equatorial Guinea', 'Seychelles',
#        'Cape Verde', 'GuineaUnknownBissau', 'Comoros',
#        'Central African Republic', 'Chad', 'Malawi', 'Burundi',
#        'Congo (Brazzaville)', 'Togo', 'Ivory Coast', 'Niger', 'Swaziland',
#        'Guinea', 'Rome, Italy', 'Northern Uganda', 'Sirte, Libya',
#        'Cairo, Egypt', 'Bamako, Mali', 'Northeast Nigeria', 'South Sudan',
#        'Ouagadougou, Burkina Faso', 'Harare, Zimbabwe', 'Nairobi, Kenya',
#        'Mozambique, Zimbabwe, Malawi', 'Tigray, Ethiopia',
#        'Juba, South Sudan', 'Coast of presentUnknownday Brazil',
#        'São Paulo', 'Brazil', 'Rio de Janeiro', 'Sweden', 'Brasília',
#        'Amazon Rainforest', 'Germany', 'Wittenberg', 'Augsburg', 'Prague',
#        'Münster and Osnabrück', 'Königsberg', 'Poland', 'Leipzig',
#        'Vienna', 'German states', 'Versailles', 'France/Germany',
#        'Poland/Germany', 'Stalingrad (Volgograd)', 'Normandy',
#        'Reims/Berlin', 'West Germany', 'Berlin', 'Maastricht',
#        'Buenos Aires', 'Tucumán', 'Patagonia', 'Argentina',
#        'Vatican City', 'Near Mexico City', 'Yucatán Peninsula',
#        'Teotihuacan', 'Lake Texcoco', 'Tenochtitlán', 'Mexico', 'Dolores',
#        'Córdoba', 'Northern Mexico'], dtype=object)

# %%
place_corrections = {
    "Delhi": "New Delhi",
    "Whole India": "Countrywide",
    "India/Pakistan": "Multiple",
    "Calicut": "Kozhikode",
    "Plassey": "Palashi",
    "Lord's, England": "Lord's Cricket Ground, London",
    "Nationwide": "Countrywide",
    "Bombay": "Mumbai",
    "Calcutta (now Kolkata)": "Kolkata",
    "East Pakistan": "Countrywide",
    "Chauri Chaura": "Chauri Chaura, Uttar Pradesh",
    "Kashmir, Pakistan": "Azad Kashmir",
    "Federally Administered Tribal Areas": "Khyber Pakhtunkhwa",
    "Various": "Multiple",
    "Colombo, others": "Multiple",
    "Coastal Sri Lanka": "Countrywide",
    "Khunjerab Pass to Hassan Abdal": "Khunjerab Pass",
    "Han Dynasty China": "Countrywide", 
    "Yuan Dynasty China": "Countrywide", 
    "Ming Dynasty China": "Countrywide",
    "Chang'an": "Xi'an", 
    "Nanking": "Nanjing",
    "Mongol Empire": "Countrywide",
    "Kievan Rus'": "Multiple",
    "Petrograd (Saint Petersburg)": "Saint Petersburg",
    "BrestUnknownLitovsk (now Brest, Belarus)": "Brest",
    "Soviet Union": "Multiple",
    "Manchuria, Korea": "Countrywide",
    "China to the Mediterranean": "Multiple",
    "Southeast Asia, Africa": "Multiple",
    "Jiangxi to Shaanxi": "Multiple",
    "Hangzhou to Beijing": "Multiple",
    "Leningrad (now Saint Petersburg)": "Saint Petersburg",
    "Stalingrad (now Volgograd)": "Volgograd",
    "HeianUnknownkyō (Kyoto)": "Kyoto",
    "Edo (Tokyo)": "Tokyo",
    "Soviet Russia": "Countrywide",
    "Korea, China": "Multiple",
    "Manchuria, China": "Countrywide",
    "USA, Europe": "Multiple",
    "Korea": "Countrywide",
    "Near Beijing, China": "Beijing",
    "Czechoslovakia": "Countrywide",
    "Beslan, North Ossetia": "Beslan",
    "Hiroshima": "Hiroshima",
    "Sydney Cove": "Sydney",
    "New South Wales, Victoria": "Multiple",
    "Entire Australia": "Countrywide",
    "Australia, UK": "Multiple",
    "Europe, Pacific": "Multiple",
    "Global": "Multiple",
    "Canberra, London": "Multiple",
    "Waitangi": "Waitangi",
    "Tarawera": "Mount Tarawera",
    "Otago, West Coast": "Multiple",
    "Kyoto, Japan": "Kyoto",
    "Gyeongbokgung Palace": "Gyeongbokgung Palace, Seoul",
    "Shanghai, China": "Shanghai",
    "Korean Peninsula, Manchuria": "Countrywide",
    "Vietnam, US": "Countrywide",
    "South Vietnam": "Countrywide",
    "North Vietnam": "Countrywide",
    "Central Vietnam": "Countrywide",
    "Southern Vietnam": "Countrywide",
    "Northern Vietnam": "Countrywide",
    "Najd, Hejaz": "Multiple",
    "Istanbul, Turkey": "Istanbul",
    "Eastern Province": "Countrywide",
    "Kuwait, Saudi Arabia": "Multiple",
    "Malaya": "Countrywide",
    "Mesopotamia": "Countrywide",
    "Persia": "Countrywide",
    "Peninsular": "Malay Peninsula",
    "Addu Atoll": "Addu Atoll",
    "Iraq/Iran border": "Multiple",
    "From Almaty to Astana": "Multiple",
    "Astana": "Nur-Sultan",
    "NurUnknownSultan": "Nur-Sultan",
    "Wall Street, NY": "Wall Street, New York",
    "USUnknownMexico Border": "US-Mexico Border",
    "Confederate States": "Southern United States",
    "Fukushima Prefecture": "Fukushima",
    "Cuba, Philippines": "Multiple",
    "Southwestern USA": "Southwestern United States",
    "Southeastern USA": "Southeastern United States",
    "USA, Canada": "Multiple",
    "Scotland and England": "Multiple",
    "Kansas, Nebraska": "Multiple",
    "Western Territories": "Multiple",
    "Supreme Court": "Supreme Court, Washington D.C.",
    "Trafalgar": "Cape Trafalgar",
    "Parliament": "Parliament, London",
    "London and nationwide": "London",
    "Stockton to Darlington": "Multiple",
    "Skies over Britain": "Space",
    "Constantinople (Impact on Italy)": "Istanbul",
    "Utrecht (Impact on Italy)": "Utrecht",
    "Caribbean, Pacific": "Multiple",
    "Cuba, Philippines, Puerto Rico, Guam": "Multiple",
    "Americas": "Multiple",
    "Between MadridUnknownSeville": "Multiple",
    "Spanish America": "Multiple",
    "Gadir (Cádiz)": "Cadiz",
    "Guadalete River": "Guadalete River",
    "Fredrikshamn": "Frederikshavn",
    "Benin (Dahomey)": "Countrywide",
    "Congo (DRC)": "Countrywide",
    "GuineaUnknownBissau": "Countrywide",
    "Congo (Brazzaville)": "Countrywide",
    "Ivory Coast": "Countrywide",
    "Swaziland": "Countrywide",
    "Königsberg": "Kaliningrad",
    "France/Germany": "Multiple",
    "Coast of presentUnknownday Brazil": "Brazilian Coast",
    "Mozambique, Zimbabwe, Malawi": "Multiple",
    "Poland/Germany": "Multiple",
    "Stalingrad (Volgograd)": "Volgograd",
    "Reims/Berlin": "Multiple",
    "West Germany": "Countrywide",
    "Near Mexico City": "Mexico City",
    "Tenochtitlán": "Mexico City",
    "Dolores": "Dolores Hidalgo",
    "Córdoba": "Córdoba, Veracruz",
    "Moon": "Space",
    "Mars": "Space",
    'India': 'Countrywide', 
    'United Kingdom': 'Countrywide',
    'UK': 'Countrywide',
    'Pakistan': 'Countrywide',
    'Sri Lanka': 'Countrywide', 
    'China': 'Countrywide',
    'Russia': 'Countrywide', 
    'Japan': 'Countrywide', 
    'Australia': 'Countrywide', 
    'New Zealand': 'Countrywide', 
    'Korea': 'Countrywide',
    'South Korea': 'Countrywide', 
    'North Korea': 'Countrywide', 
    'Vietnam': 'Countrywide', 
    'Saudi Arabia': 'Countrywide',
    'Singapore': 'Countrywide', 
    'Iran': 'Countrywide', 
    'Iraq': 'Countrywide', 
    'Kazakhstan': 'Countrywide', 
    'Uzbekistan': 'Countrywide', 
    'Bhutan': 'Countrywide',
    'Maldives': 'Countrywide',
    'Malaysia': 'Countrywide', 
    'Malacca': 'Countrywide', 
    'Central Asia': 'Countrywide', 
    'Punakha': 'Countrywide',
    'Taiwan': 'Countrywide', 
    'Indonesia': 'Countrywide', 
    'Philippines': 'Countrywide', 
    'Thailand': 'Countrywide',
    'United States': 'Countrywide',
    'USA': 'Countrywide', 
    'Canada': 'Countrywide', 
    'France': 'Countrywide', 
    'Italy': 'Countrywide', 
    'Spain': 'Countrywide',
    'South Africa': 'Countrywide',
    'Gibraltar': 'Countrywide', 
    'Denmark': 'Countrywide', 
    'Norway': 'Countrywide', 
    'Finland': 'Countrywide',
    'Nigeria': 'Countrywide', 
    'Kenya': 'Countrywide', 
    'Algeria': 'Countrywide', 
    'Libya': 'Countrywide', 
    'Tunisia': 'Countrywide', 
    'Zimbabwe': 'Countrywide',
    'Morocco': 'Countrywide', 
    'Angola': 'Countrywide', 
    'Egypt': 'Countrywide', 
    'Rwanda': 'Countrywide', 
    'Uganda': 'Countrywide', 
    'Somalia': 'Countrywide',
    'Botswana': 'Countrywide', 
    'Namibia': 'Countrywide', 
    'Sudan': 'Countrywide', 
    "Côte d'Ivoire": 'Countrywide', 
    'Ghana': 'Countrywide',
    'Tanzania': 'Countrywide', 
    'Madagascar': 'Countrywide', 
    'Ethiopia': 'Countrywide', 
    'Mozambique': 'Countrywide', 
    'Zambia': 'Countrywide',
    "Senegal": "Countrywide",
    "Democratic Republic of the Congo": "Countrywide",
    "Sierra Leone": "Countrywide",
    "Mali": "Countrywide",
    "Burkina Faso": "Countrywide",
    "Cameroon": "Countrywide",
    "Eritrea": "Countrywide",
    "Benin": "Countrywide",
    "Mauritania": "Countrywide",
    "Gabon": "Countrywide",
    "Lesotho": "Countrywide",
    "Gambia": "Countrywide",
    "Djibouti": "Countrywide",
    "Equatorial Guinea": "Countrywide",
    "Seychelles": "Countrywide",
    "Cape Verde": "Countrywide",
    "Guinea-Bissau": "Countrywide",
    "Comoros": "Countrywide",
    "Central African Republic": "Countrywide",
    "Chad": "Countrywide",
    "Malawi": "Countrywide",
    "Burundi": "Countrywide",
    "Republic of the Congo": "Countrywide",
    "Togo": "Countrywide",
    "Niger": "Countrywide",
    "Eswatini": "Countrywide",
    "Guinea": "Countrywide",
    "South Sudan": "Countrywide",
    "Brazil": "Countrywide",
    "Germany": "Countrywide",
    "Argentina": "Countrywide",
    "Mexico": "Countrywide"
}

df['Place Name'] = df['Place Name'].replace(place_corrections)

df['Place Name'].unique()
# Out:
# array(['Indus Valley', 'Punjab', 'New Delhi', 'Panipat', 'Countrywide',
#        'Multiple', 'Bangladesh', 'Pokhran', 'Mumbai', 'Kozhikode',
#        'Palashi', 'Meerut', 'Bengal', 'Punjab, Haryana', 'Amritsar',
#        'Kargil, Ladakh', 'Ayodhya', 'Maharashtra',
#        'Border regions of India', 'Pokhran, Rajasthan',
#        'Bhopal, Madhya Pradesh', 'Kandahar, Afghanistan',
#        'Jammu & Kashmir', 'Gujarat', 'Uttar Pradesh',
#        "Lord's Cricket Ground, London", 'Uttarakhand', 'Space',
#        'Pulwama, Jammu and Kashmir', 'Paris, France',
#        'Uri, Jammu and Kashmir', 'Chauri Chaura, Uttar Pradesh', 'Dandi',
#        'London', 'Lahore', 'Kolkata', 'Bangalore', 'Agra', 'Kashmir',
#        'New York', 'Dhaka', 'Chagai, Balochistan', 'Kargil, Kashmir',
#        'Azad Kashmir', 'Rawalpindi', 'North Waziristan', 'Peshawar',
#        'Islamabad', 'Kartarpur', 'Khyber Pakhtunkhwa', 'Pulwama, India',
#        'Siachen Glacier', 'Karachi', 'Oslo, Norway', 'Khunjerab Pass',
#        'Xichang, China', 'Gwadar', 'Colombo', 'Mullaitivu',
#        'Mahaweli River', 'Sigiriya', 'Imperial court', 'Northern China',
#        "Xi'an", 'Kaifeng', 'Nanjing', 'Southern China', 'Wuchang',
#        'Hong Kong', 'Beijing', 'Yangtze River', 'Macau', 'Shanghai',
#        "Chang'an, Luoyang", 'Beijing, Shanghai', 'Geneva', 'Guangdong',
#        'South China Sea', 'Brussels', 'Kiev', 'Kulikovo Field', 'Moscow',
#        'Saint Petersburg', 'Brest', 'Kronstadt', 'Volgograd',
#        'Yalta, Crimea', 'Baikonur Cosmodrome', 'Cuba', 'Afghanistan',
#        'Chernobyl, Ukraine', 'Berlin, Germany', 'Beslan', 'Crimea',
#        'Syria', 'Salisbury, UK', 'Asuka', 'Nara', 'Kyoto', 'Kamakura',
#        'Kyushu', 'Muromachi, Kyoto', 'Tanegashima', 'Azuchi', 'Tokyo',
#        'Hiroshima, Nagasaki', 'Edo Bay (Tokyo Bay)', 'Washington D.C.',
#        'Tokyo Bay', 'San Francisco', 'Osaka', 'Kobe', 'Fukushima',
#        'Seoul', 'Sydney', 'Tasmania', 'Ballarat, Victoria',
#        'Gallipoli, Turkey', 'Darwin, Northern Territory',
#        'Papua New Guinea', 'Myall Creek, New South Wales',
#        'Melbourne, Victoria', 'Queensland', 'Victoria',
#        'High Court of Australia', 'Canberra', 'Port Arthur, Tasmania',
#        'Northern Territory', 'Indian Ocean', 'Waitangi',
#        'Various locations', 'Unknown', 'Mount Tarawera', 'Auckland',
#        'Christchurch', 'Korean Peninsula', 'Gyeongbokgung Palace, Seoul',
#        '38th Parallel North', 'Pyongyang', 'Jeju Island', 'Panmunjom',
#        'Sea of Japan', 'Kilju County', 'Gwangju', 'South Korea, Japan',
#        'Seongju County', 'Điện Biên Phủ', 'Gulf of Tonkin', 'Paris',
#        'Saigon', 'Southeast Asia', 'Hanoi', 'Da Nang',
#        'Hanoi, Ho Chi Minh City', 'Yên Bái', 'Ba Đình Square, Hanoi',
#        'Diriyah', 'Najd', 'Hejaz', 'Jeddah', 'Dammam', 'Dhahran',
#        'Yemen border', 'Mecca', 'Riyadh', 'Taif', 'Middle East', 'Cairo',
#        'Persian Gulf', 'Yemen', 'Istanbul', 'Sentosa', 'Bukhara',
#        'Samarkand', 'Thimphu', 'Babylon', 'Baghdad',
#        'Northern Kazakhstan', 'Kengir', 'Central asia', 'Malay Peninsula',
#        'Basra', 'Tashkent', 'Addu Atoll', 'Nur-Sultan', 'Kuala Lumpur',
#        'Mosul', 'Zhanaozen', 'Malé', 'Southern Indian Ocean',
#        'Mount Takamagahara', 'Taiwan Strait', 'Guam', 'Java Sea',
#        'Kathmandu', 'Okinawa', 'Musi River', 'Phuket', 'Yellow Sea',
#        'Wenzhou', 'Tablas Strait', 'Sidoarjo', 'Tham Luang Cave',
#        'Philadelphia', 'Midwest', 'Southern USA', 'Wall Street, New York',
#        'NY, VA, PA', 'Topeka, Kansas', 'Cape Canaveral, FL',
#        'Oklahoma City, OK', 'Gulf Coast', 'US-Mexico Border',
#        'International', 'East Coast', 'Dallas, Texas', 'New York, NY',
#        'Silicon Valley, CA', 'Charlottesville, VA', 'Boston, MA',
#        'Western USA', 'California', 'Seneca Falls, NY',
#        'Southern United States', 'Promontory, Utah', 'Kitty Hawk, NC',
#        'Southwestern United States', 'Supreme Court, Washington D.C.',
#        'Panama', 'Europe', 'Pearl Harbor, HI', 'Western Europe',
#        'San Francisco, CA', 'Jamestown, VA', 'Salem, MA',
#        'Eastern North America', 'Missouri', 'Southeastern United States',
#        'Alaska', 'Ottawa', 'Vimy Ridge, France', 'Toronto',
#        'Newfoundland', 'Oka, Quebec', 'Vancouver', 'Fort McMurray, AB',
#        'Northern Canada', 'Quebec', 'Red River Colony', 'Yukon',
#        'Halifax, NS', 'British Columbia', 'Leduc, Alberta', 'London, UK',
#        'Runnymede', 'English Channel', 'England', 'Cape Trafalgar',
#        'Parliament, London', 'Suez Canal', 'Liverpool',
#        'Falkland Islands', 'Northern Ireland', 'Aldermaston', 'Scotland',
#        'Windsor', 'Waterloo', "St Mary's Hospital", 'Westminster Abbey',
#        'Roslin Institute', 'Gleneagles', 'Salisbury Plain', 'Oxford',
#        'Agincourt', 'Derry', 'Tours', 'Verdun', 'Rome', 'Clermont',
#        'Orléans', 'Nantes', 'Clermont (announced)', 'Lodi', 'Florence',
#        'Venice', 'Utrecht', 'Turin', 'Milan', "L'Aquila", 'Giglio Island',
#        'Atlantic Ocean', 'Granada', 'Pyrenees', 'Madrid',
#        'Atlantic Ocean near Cape Trafalgar', 'Iberian Peninsula', 'Cadiz',
#        'Barcelona', 'Catalonia', 'Valle de los Caídos', 'Basque Country',
#        'Altamira', 'Worldwide', 'Johannesburg', 'Guadalete River',
#        'Kalmar, Sweden', 'Roskilde', 'Copenhagen', 'Lapland', 'Schleswig',
#        'Oslo', 'Frederikshavn', 'Kimberley', 'Great Zimbabwe',
#        'Marrakech', 'Sharpeville', 'Algiers', 'Arusha, Tanzania',
#        'Rome, Italy', 'Northern Uganda', 'Sirte, Libya', 'Cairo, Egypt',
#        'Bamako, Mali', 'Northeast Nigeria', 'Ouagadougou, Burkina Faso',
#        'Harare, Zimbabwe', 'Nairobi, Kenya', 'Tigray, Ethiopia',
#        'Juba, South Sudan', 'Brazilian Coast', 'São Paulo',
#        'Rio de Janeiro', 'Sweden', 'Brasília', 'Amazon Rainforest',
#        'Wittenberg', 'Augsburg', 'Prague', 'Münster and Osnabrück',
#        'Kaliningrad', 'Poland', 'Leipzig', 'Vienna', 'German states',
#        'Versailles', 'Normandy', 'Berlin', 'Maastricht', 'Buenos Aires',
#        'Tucumán', 'Patagonia', 'Vatican City', 'Mexico City',
#        'Yucatán Peninsula', 'Teotihuacan', 'Lake Texcoco',
#        'Dolores Hidalgo', 'Córdoba, Veracruz', 'Northern Mexico'],
#       dtype=object)

# %%
df = df.dropna(subset=['Place Name'])
df = df.dropna(subset=['Country'])
df = df[~df['Place Name'].isin(['Multiple', 'Countrywide', 'Space'])]

# %%
# Initialize the geocoder
geolocator = Nominatim(user_agent="geoapiExercises")

# To prevent hitting the service too hard, wrap the geolocator with a rate limiter
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=2)

# Function to apply to each row in your DataFrame
def geocode_place(row):
    # Combine the place name and country into one search query
    query = f"{row['Place Name']}, {row['Country']}"
    try:
        # Attempt to geocode using the combined query
        location = geocode(query)
        if location:
            return pd.Series([location.latitude, location.longitude])
        else:
            return pd.Series([None, None])
    except:
        return pd.Series([None, None])

# Apply the function to the DataFrame
df[['latitude', 'longitude']] = df.apply(geocode_place, axis=1)
# Out:
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Paris, France',), **{}).
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 500, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 403
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderInsufficientPrivileges: Non-successful status code 403
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Paris, France',), **{}).
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 500, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 403
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderInsufficientPrivileges: Non-successful status code 403
# RateLimiter swallowed an error after 2 retries. Called with (*('Paris, France',), **{}).
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 500, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 403
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderInsufficientPrivileges: Non-successful status code 403
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Multiple, France',), **{}).
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 466, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 461, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/ssl.py", line 1275, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/ssl.py", line 1133, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 714, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 468, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 357, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 798, in urlopen
#     retries = retries.increment(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Multiple%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 482, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Multiple%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 494, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Multiple%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Multiple, France',), **{}).
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 466, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 461, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/ssl.py", line 1275, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/ssl.py", line 1133, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 714, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 468, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 357, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 798, in urlopen
#     retries = retries.increment(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Multiple%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 482, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Multiple%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 494, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Multiple%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter swallowed an error after 2 retries. Called with (*('Multiple, France',), **{}).
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 466, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 461, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/ssl.py", line 1275, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/ssl.py", line 1133, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 714, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 468, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 357, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 798, in urlopen
#     retries = retries.increment(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Multiple%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 482, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Multiple%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 494, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Multiple%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Paris, France',), **{}).
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 466, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 461, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/ssl.py", line 1275, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/ssl.py", line 1133, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 714, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 468, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 357, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 798, in urlopen
#     retries = retries.increment(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Paris%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 482, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Paris%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 494, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Paris%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Paris, France',), **{}).
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 466, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 461, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/ssl.py", line 1275, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/ssl.py", line 1133, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 714, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 468, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 357, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 798, in urlopen
#     retries = retries.increment(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Paris%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 482, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Paris%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 494, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Paris%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter swallowed an error after 2 retries. Called with (*('Paris, France',), **{}).
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 466, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 461, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/ssl.py", line 1275, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/ssl.py", line 1133, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 714, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 468, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 357, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 798, in urlopen
#     retries = retries.increment(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Paris%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 482, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Paris%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 494, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Paris%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Paris, France',), **{}).
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 500, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 503
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderTimedOut: Non-successful status code 503
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Paris, France',), **{}).
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 466, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 461, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/ssl.py", line 1275, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/ssl.py", line 1133, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 714, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 468, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 357, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 798, in urlopen
#     retries = retries.increment(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Paris%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 482, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Paris%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 494, in _request
# ...
#     res = self.func(*args, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderTimedOut: Non-successful status code 503
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Paris, France',), **{}).
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 466, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 461, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/ssl.py", line 1275, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/ssl.py", line 1133, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 714, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 468, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 357, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 798, in urlopen
#     retries = retries.increment(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Paris%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 482, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Paris%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 494, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Paris%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter swallowed an error after 2 retries. Called with (*('Paris, France',), **{}).
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 466, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 461, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/ssl.py", line 1275, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/ssl.py", line 1133, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 714, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 468, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 357, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/connectionpool.py", line 798, in urlopen
#     retries = retries.increment(
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Paris%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 482, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Paris%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 494, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Paris%2C+France&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Multiple, France',), **{}).
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 500, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 503
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderTimedOut: Non-successful status code 503
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Multiple, France',), **{}).
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/adapters.py", line 500, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 503
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/killianhd/anaconda3/envs/ada/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderTimedOut: Non-successful status code 503

# %%
df.to_csv('World Important Dates with Coordinates.csv', index=False, encoding='utf-8')

# %%
df = pd.read_csv('World Important Dates with Coordinates.csv')
df.head()
# Out:
#    Sl. No                        NameOfIncident     Date     Month     Year  \
# 0       1  Indus Valley Civilization Flourishes  Unknown   Unknown  2600 BC
# 1       2               Battle of the Ten Kings  Unknown   Unknown  1400 BC
# 2       6  Establishment of the Delhi Sultanate  Unknown   Unknown     1206
# 3       7                     Battle of Panipat       21     April     1526
# 4      10      IndoUnknownPakistani War of 1971        3  December     1971
#
#   Country   TypeOfEvent     PlaceName  \
# 0   India  Civilization  Indus Valley
# 1   India        Battle        Punjab
# 2   India     Political     New Delhi
# 3   India        Battle       Panipat
# 4   India           War    Bangladesh
#
#                                               Impact  \
# 0  Development of one of the world's earliest urb...
# 1  Rigvedic tribes consolidated their control ove...
# 2          Muslim rule established in parts of India
# 3           Foundation of the Mughal Empire in India
# 4              Led to the independence of Bangladesh
#
#                         AffectedPopulation ImportantPersonGroupResponsible  \
# 0                        Local inhabitants             Indus Valley people
# 1                          Rigvedic tribes                           Sudas
# 2  People of Delhi and surrounding regions   QutbUnknownudUnknowndin Aibak
# 3                 Northern Indian kingdoms                           Babur
# 4                Bengalis in East Pakistan   Indian Military, Mukti Bahini
#
#     Outcome   latitude  longitude
# 0  Positive  34.140948  77.483101
# 1  Positive  30.929321  75.500484
# 2     Mixed  28.613895  77.209006
# 3     Mixed  29.391275  76.977167
# 4  Negative   9.800732  77.244461

# %%
#Mapping to name of the columns to be used in javascript
rename_mapping = {
    'Name of Incident': 'NameOfIncident',
    'Type of Event': 'TypeOfEvent',
    'Place Name': 'PlaceName',
    'Affected Population': 'AffectedPopulation',
    'Important Person/Group Responsible': 'ImportantPersonGroupResponsible',
}

df = df.rename(columns=rename_mapping)
df.head()
# Out:
#    Sl. No                        NameOfIncident     Date     Month     Year  \
# 0       1  Indus Valley Civilization Flourishes  Unknown   Unknown  2600 BC
# 1       2               Battle of the Ten Kings  Unknown   Unknown  1400 BC
# 2       6  Establishment of the Delhi Sultanate  Unknown   Unknown     1206
# 3       7                     Battle of Panipat       21     April     1526
# 4      10      IndoUnknownPakistani War of 1971        3  December     1971
#
#   Country   TypeOfEvent     PlaceName  \
# 0   India  Civilization  Indus Valley
# 1   India        Battle        Punjab
# 2   India     Political     New Delhi
# 3   India        Battle       Panipat
# 4   India           War    Bangladesh
#
#                                               Impact  \
# 0  Development of one of the world's earliest urb...
# 1  Rigvedic tribes consolidated their control ove...
# 2          Muslim rule established in parts of India
# 3           Foundation of the Mughal Empire in India
# 4              Led to the independence of Bangladesh
#
#                         AffectedPopulation ImportantPersonGroupResponsible  \
# 0                        Local inhabitants             Indus Valley people
# 1                          Rigvedic tribes                           Sudas
# 2  People of Delhi and surrounding regions   QutbUnknownudUnknowndin Aibak
# 3                 Northern Indian kingdoms                           Babur
# 4                Bengalis in East Pakistan   Indian Military, Mukti Bahini
#
#     Outcome   latitude  longitude
# 0  Positive  34.140948  77.483101
# 1  Positive  30.929321  75.500484
# 2     Mixed  28.613895  77.209006
# 3     Mixed  29.391275  76.977167
# 4  Negative   9.800732  77.244461

# %%
df = pd.read_csv('World Important Dates with Coordinates.csv')
df.head()
# Out:
#    Sl. No                        NameOfIncident     Date     Month     Year  \
# 0       1  Indus Valley Civilization Flourishes  Unknown   Unknown  2600 BC
# 1       2               Battle of the Ten Kings  Unknown   Unknown  1400 BC
# 2       6  Establishment of the Delhi Sultanate  Unknown   Unknown     1206
# 3       7                     Battle of Panipat       21     April     1526
# 4      10      IndoUnknownPakistani War of 1971        3  December     1971
#
#   Country   TypeOfEvent     PlaceName  \
# 0   India  Civilization  Indus Valley
# 1   India        Battle        Punjab
# 2   India     Political     New Delhi
# 3   India        Battle       Panipat
# 4   India           War    Bangladesh
#
#                                               Impact  \
# 0  Development of one of the world's earliest urb...
# 1  Rigvedic tribes consolidated their control ove...
# 2          Muslim rule established in parts of India
# 3           Foundation of the Mughal Empire in India
# 4              Led to the independence of Bangladesh
#
#                         AffectedPopulation ImportantPersonGroupResponsible  \
# 0                        Local inhabitants             Indus Valley people
# 1                          Rigvedic tribes                           Sudas
# 2  People of Delhi and surrounding regions   QutbUnknownudUnknowndin Aibak
# 3                 Northern Indian kingdoms                           Babur
# 4                Bengalis in East Pakistan   Indian Military, Mukti Bahini
#
#     Outcome   latitude  longitude
# 0  Positive  34.140948  77.483101
# 1  Positive  30.929321  75.500484
# 2     Mixed  28.613895  77.209006
# 3     Mixed  29.391275  76.977167
# 4  Negative   9.800732  77.244461

# %%
df = df[df.latitude.isna()]

# %%
df.head()
# Out:
#     Sl. No                          NameOfIncident     Date     Month  Year  \
# 17      27                   SinoUnknownIndian War       20   October  1962
# 20      32             Kandahar Hijacking (IC 814)       24  December  1999
# 27      42  Historic Win in Cricket World Cup 1983       25      June  1983
# 31      55      Historic Solar Alliance Initiative       30  November  2015
# 55      92                         Kargil Conflict  Unknown   Unknown  1999
#
#      Country                TypeOfEvent                      PlaceName  \
# 17     India          Military Conflict        Border regions of India
# 20     India                  Terrorism          Kandahar, Afghanistan
# 27     India                     Sports  Lord's Cricket Ground, London
# 31     India  International Cooperation                  Paris, France
# 55  Pakistan          Military Conflict                Kargil, Kashmir
#
#                                                Impact  \
# 17  Highlighted the border disputes and led to mil...
# 20  Highlighted issues in aviation security and te...
# 27  Marked India's first Cricket World Cup win, bo...
# 31  India coUnknownlaunched the International Sola...
# 55  A military conflict between India and Pakistan...
#
#                 AffectedPopulation ImportantPersonGroupResponsible   Outcome  \
# 17              Border communities                    India, China  Negative
# 20                Passengers, crew    Hijackers, Indian Government  Negative
# 27              Indian sports fans             Indian cricket team  Positive
# 31                Global community     Government of India, France  Positive
# 55  Citizens of India and Pakistan              India and Pakistan  Negative
#
#     latitude  longitude
# 17       NaN        NaN
# 20       NaN        NaN
# 27       NaN        NaN
# 31       NaN        NaN
# 55       NaN        NaN

# %%
# Initialize the geocoder
geolocator = Nominatim(user_agent="geoapiDataVizProjectK")

# To prevent hitting the service too hard, wrap the geolocator with a rate limiter
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=2)

# Function to apply to each row in your DataFrame
def geocode_place(row):
    # If the latitude is already known, return it
    if pd.notnull(row['latitude']):
        return pd.Series([row['latitude'], row['longitude']])
    # Combine the place name and country into one search query
    query = f"{row['PlaceName']}, {row['Country']}"
    try:
        # Attempt to geocode using the combined query
        location = geocode(query)
        if location:
            return pd.Series([location.latitude, location.longitude])
        else:
            return pd.Series([None, None])
    except:
        return pd.Series([None, None])

# Apply the function to the DataFrame
df[['latitude', 'longitude']] = df.apply(geocode_place, axis=1)

# %%
df.head()
# Out:
#    Sl. No                        NameOfIncident     Date     Month     Year  \
# 0       1  Indus Valley Civilization Flourishes  Unknown   Unknown  2600 BC
# 1       2               Battle of the Ten Kings  Unknown   Unknown  1400 BC
# 2       6  Establishment of the Delhi Sultanate  Unknown   Unknown     1206
# 3       7                     Battle of Panipat       21     April     1526
# 4      10      IndoUnknownPakistani War of 1971        3  December     1971
#
#   Country   TypeOfEvent     PlaceName  \
# 0   India  Civilization  Indus Valley
# 1   India        Battle        Punjab
# 2   India     Political     New Delhi
# 3   India        Battle       Panipat
# 4   India           War    Bangladesh
#
#                                               Impact  \
# 0  Development of one of the world's earliest urb...
# 1  Rigvedic tribes consolidated their control ove...
# 2          Muslim rule established in parts of India
# 3           Foundation of the Mughal Empire in India
# 4              Led to the independence of Bangladesh
#
#                         AffectedPopulation ImportantPersonGroupResponsible  \
# 0                        Local inhabitants             Indus Valley people
# 1                          Rigvedic tribes                           Sudas
# 2  People of Delhi and surrounding regions   QutbUnknownudUnknowndin Aibak
# 3                 Northern Indian kingdoms                           Babur
# 4                Bengalis in East Pakistan   Indian Military, Mukti Bahini
#
#     Outcome   latitude  longitude
# 0  Positive  34.140948  77.483101
# 1  Positive  30.929321  75.500484
# 2     Mixed  28.613895  77.209006
# 3     Mixed  29.391275  76.977167
# 4  Negative   9.800732  77.244461

# %%
df.to_csv('World Important Dates with Coordinates.csv', index=False, encoding='utf-8')
